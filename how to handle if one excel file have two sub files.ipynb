# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns
import pandas_profiling

# %%
# !pip install xlrd

# %%
df  = pd.concat(pd.read_excel(r"C:\Users\LENOVO\Desktop\sheets.xlsx",sheet_name=None),
ignore_index=True)

# %%
df
# Out:
#     1     20    41    61      1597    1609    1627    1973    1992    1999  \
# 0      1   NaN   NaN  62.0  1587.0     NaN     NaN     NaN     NaN  1999.0
# 1      1   NaN   NaN  63.0  1577.0     NaN     NaN     NaN     NaN  1999.0
# 2      1   NaN   NaN  64.0  1567.0     NaN     NaN     NaN     NaN  1999.0
# 3      1   NaN   NaN  65.0  1557.0     NaN     NaN     NaN     NaN  1999.0
# 4      1   NaN   NaN  66.0  1547.0     NaN     NaN     NaN     NaN  1999.0
# 5      1   NaN   NaN  67.0  1537.0     NaN     NaN     NaN     NaN  1999.0
# 6      1   NaN   NaN  68.0  1527.0     NaN     NaN     NaN     NaN  1999.0
# 7      1   NaN   NaN  69.0  1517.0     NaN     NaN     NaN     NaN  1999.0
# 8      1   NaN   NaN  70.0  1507.0     NaN     NaN     NaN     NaN  1999.0
# 9      1   NaN   NaN  71.0  1497.0     NaN     NaN     NaN     NaN  1999.0
# 10     1   NaN   NaN  72.0  1487.0     NaN     NaN     NaN     NaN  1999.0
# ...

# %%
df.isna().sum()
# Out:
# 1        0
# 20      38
# 41      39
# 61      39
# 1597    39
# 1609    39
# 1627    38
# 1973    39
# 1992    38
# 1999    39
# 2005    39
# 2073    38
# 2130    39
# dtype: int64

# %%
df.replace(np.nan,2,inplace=True)

# %%
df.isna().sum()
# Out:
# 1       0
# 20      0
# 41      0
# 61      0
# 1597    0
# 1609    0
# 1627    0
# 1973    0
# 1992    0
# 1999    0
# 2005    0
# 2073    0
# 2130    0
# dtype: int64

# %%
df.dtypes
# Out:
# 1         int64
# 20      float64
# 41      float64
# 61      float64
# 1597    float64
# 1609    float64
# 1627    float64
# 1973    float64
# 1992    float64
# 1999    float64
# 2005    float64
# 2073    float64
# 2130    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 13 columns):
# 1       58 non-null int64
# 20      58 non-null float64
# 41      58 non-null float64
# 61      58 non-null float64
# 1597    58 non-null float64
# 1609    58 non-null float64
# 1627    58 non-null float64
# 1973    58 non-null float64
# 1992    58 non-null float64
# 1999    58 non-null float64
# 2005    58 non-null float64
# 2073    58 non-null float64
# 2130    58 non-null float64
# dtypes: float64(12), int64(1)
# memory usage: 6.0 KB

# %%
df.dtypes
# Out:
# 1       float64
# 20      float64
# 41      float64
# 61      float64
# 1597    float64
# 1609    float64
# 1627    float64
# 1973    float64
# 1992    float64
# 1999    float64
# 2005    float64
# 2073    float64
# 2130    float64
# dtype: object

# %%
df.columns
# Out:
# Int64Index([1, 20, 41, 61, 1597, 1609, 1627, 1973, 1992, 1999, 2005, 2073,
#             2130],
#            dtype='int64')

# %%
sns.heatmap(df)

# %%
df.head()
# Out:
#    1     20    41    61      1597  1609  1627  1973  1992    1999  2005  2073  \
# 0   1.0   2.0   2.0  62.0  1587.0   2.0   2.0   2.0   2.0  1999.0   2.0   2.0
# 1   1.0   2.0   2.0  63.0  1577.0   2.0   2.0   2.0   2.0  1999.0   2.0   2.0
# 2   1.0   2.0   2.0  64.0  1567.0   2.0   2.0   2.0   2.0  1999.0   2.0   2.0
# 3   1.0   2.0   2.0  65.0  1557.0   2.0   2.0   2.0   2.0  1999.0   2.0   2.0
# 4   1.0   2.0   2.0  66.0  1547.0   2.0   2.0   2.0   2.0  1999.0   2.0   2.0
#
#      2130
# 0  2051.0
# 1  1972.0
# 2  1893.0
# 3  1814.0
# 4  1735.0

# %%
df.tail()
# Out:
#     1     20    41    61    1597    1609  1627    1973  1992  1999    2005  \
# 53   1.0   2.0  56.0   2.0   2.0  1603.0   2.0  1992.0   2.0   2.0  2108.0
# 54   1.0   2.0  57.0   2.0   2.0  1605.0   2.0  2008.0   2.0   2.0  2075.0
# 55   1.0   2.0  58.0   2.0   2.0  1620.0   2.0  2001.0   2.0   2.0  2037.0
# 56   1.0   2.0  59.0   2.0   2.0  1616.0   2.0  2016.0   2.0   2.0  2052.0
# 57   1.0   2.0  60.0   2.0   2.0  1611.0   2.0  2019.0   2.0   2.0  2149.0
#
#     2073  2130
# 53   2.0   2.0
# 54   2.0   2.0
# 55   2.0   2.0
# 56   2.0   2.0
# 57   2.0   2.0

# %%
df.describe()
# Out:
#        1          20         41         61           1597         1609  \
# count  58.0  58.000000  58.000000  58.000000    58.000000    58.000000
# mean    1.0  11.827586  18.051724  24.603448   491.741379   528.758621
# std     0.0  14.085127  23.412714  32.819517   708.487035   761.381876
# min     1.0   2.000000   2.000000   2.000000     2.000000     2.000000
# 25%     1.0   2.000000   2.000000   2.000000     2.000000     2.000000
# 50%     1.0   2.000000   2.000000   2.000000     2.000000     2.000000
# 75%     1.0  25.750000  45.750000  65.750000  1444.500000  1599.750000
# max     1.0  40.000000  60.000000  80.000000  1587.000000  1654.000000
#
#               1627         1973         1992         1999         2005  \
# count    58.000000    58.000000    58.000000    58.000000    58.000000
# mean    556.741379   653.534483   704.931034   656.189655   679.517241
# std     771.578868   942.491774   977.999782   945.443857   979.682033
# ...

# %%
df.columns
# Out:
# Int64Index([1, 20, 41, 61, 1597, 1609, 1627, 1973, 1992, 1999, 2005, 2073,
#             2130],
#            dtype='int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 13 columns):
# 1       58 non-null float64
# 20      58 non-null float64
# 41      58 non-null float64
# 61      58 non-null float64
# 1597    58 non-null float64
# 1609    58 non-null float64
# 1627    58 non-null float64
# 1973    58 non-null float64
# 1992    58 non-null float64
# 1999    58 non-null float64
# 2005    58 non-null float64
# 2073    58 non-null float64
# 2130    58 non-null float64
# dtypes: float64(13)
# memory usage: 6.0 KB

# %%
df.isna().sum()
# Out:
# 1       0
# 20      0
# 41      0
# 61      0
# 1597    0
# 1609    0
# 1627    0
# 1973    0
# 1992    0
# 1999    0
# 2005    0
# 2073    0
# 2130    0
# dtype: int64

# %%
df.dtypes
# Out:
# 1       float64
# 20      float64
# 41      float64
# 61      float64
# 1597    float64
# 1609    float64
# 1627    float64
# 1973    float64
# 1992    float64
# 1999    float64
# 2005    float64
# 2073    float64
# 2130    float64
# dtype: object

# %%
f = pd.Series({'name':['rani','raju','manntri'],
             'age':(29,20,21),
              'gender':['f','m','m']})

# %%
f
# Out:
# name      [rani, raju, manntri]
# age                (29, 20, 21)
# gender                [f, m, m]
# dtype: object

# %%
pd.DataFrame(f)
# Out:
#                             0
# name    [rani, raju, manntri]
# age              (29, 20, 21)
# gender              [f, m, m]

# %%
df1 = pd.DataFrame({"height":[5.7,6,5.8],
                   "weight":[80,50,60]})

# %%
df2= pd.DataFrame({"name":["mujahid","bharath","shameer"],
                  "age":[23,23,60]})

# %%
da=pd.concat([df1,df2],axis=1)

# %%
da
# Out:
#    height  weight     name  age
# 0     5.7      80  mujahid   23
# 1     6.0      50  bharath   23
# 2     5.8      60  shameer   60

# %%
da=pd.concat([df1,df2],axis=0,sort=False)
da
# Out:
#    height  weight     name   age
# 0     5.7    80.0      NaN   NaN
# 1     6.0    50.0      NaN   NaN
# 2     5.8    60.0      NaN   NaN
# 0     NaN     NaN  mujahid  23.0
# 1     NaN     NaN  bharath  23.0
# 2     NaN     NaN  shameer  60.0

# %%
da=pd.concat([df1,df2],axis='rows',sort=False)
da
# Out:
#    height  weight     name   age
# 0     5.7    80.0      NaN   NaN
# 1     6.0    50.0      NaN   NaN
# 2     5.8    60.0      NaN   NaN
# 0     NaN     NaN  mujahid  23.0
# 1     NaN     NaN  bharath  23.0
# 2     NaN     NaN  shameer  60.0

# %%
da=pd.concat([df1,df2],axis='index',sort=False)
da
# Out:
#    height  weight     name   age
# 0     5.7    80.0      NaN   NaN
# 1     6.0    50.0      NaN   NaN
# 2     5.8    60.0      NaN   NaN
# 0     NaN     NaN  mujahid  23.0
# 1     NaN     NaN  bharath  23.0
# 2     NaN     NaN  shameer  60.0

# %%
da=pd.concat([df1,df2],axis='columns',sort=False)
da
# Out:
#    height  weight     name  age
# 0     5.7      80  mujahid   23
# 1     6.0      50  bharath   23
# 2     5.8      60  shameer   60

# %%
da.iloc[0]
# Out:
# height        5.7
# weight         80
# name      mujahid
# age            23
# Name: 0, dtype: object

# %%
da.loc[0]
# Out:
# height        5.7
# weight         80
# name      mujahid
# age            23
# Name: 0, dtype: object

# %%
f = pd.DataFrame({"name":["raju",'rani',"mantri","choor"],
                 "gender":['m','f','m','m'],
                 "mobile":[np.nan,2,None,np.nan]})

# %%
f
# Out:
#      name gender  mobile
# 0    raju      m     NaN
# 1    rani      f     2.0
# 2  mantri      m     NaN
# 3   choor      m     NaN

# %%
df1 = pd.DataFrame({'A': [1., np.nan, 3., 5., np.nan],  'B': [np.nan, 2., 3., np.nan, 6.]})
df2 = pd.DataFrame({'A': [5., 2., 4., np.nan, 3., 7.], 'B': [np.nan, np.nan, 3., 4., 6., 8.]})

# %%
df1.combine_first(df2)
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  2.0
# 2  3.0  3.0
# 3  5.0  4.0
# 4  3.0  6.0
# 5  7.0  8.0

# %%
df1.mean(0)
# Out:
# A    3.000000
# B    3.666667
# dtype: float64

# %%
df1.median(0)
# Out:
# A    3.0
# B    3.0
# dtype: float64

# %%
df1.mean(1)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    5.0
# 4    6.0
# dtype: float64

# %%
df1.sum()
# Out:
# A     9.0
# B    11.0
# dtype: float64

# %%
df1.sum(0,skipna=False)
# Out:
# A   NaN
# B   NaN
# dtype: float64

# %%
df1.sum(0,skipna=True)
# Out:
# A     9.0
# B    11.0
# dtype: float64

# %%
df1.sum(1,skipna=False)
# Out:
# 0    NaN
# 1    NaN
# 2    6.0
# 3    NaN
# 4    NaN
# dtype: float64

# %%
df1.sum(1,skipna=True)
# Out:
# 0    1.0
# 1    2.0
# 2    6.0
# 3    5.0
# 4    6.0
# dtype: float64

# %%
df1.cumsum()
# Out:
#      A     B
# 0  1.0   NaN
# 1  NaN   2.0
# 2  4.0   5.0
# 3  9.0   NaN
# 4  NaN  11.0

# %%
df1.cumsum(0)
# Out:
#      A     B
# 0  1.0   NaN
# 1  NaN   2.0
# 2  4.0   5.0
# 3  9.0   NaN
# 4  NaN  11.0

# %%
df1.cumsum(1)
# Out:
#      A    B
# 0  1.0  NaN
# 1  NaN  2.0
# 2  3.0  6.0
# 3  5.0  NaN
# 4  NaN  6.0

# %%
frame = pd.DataFrame(np.random.randn(1000, 5),   columns=['a', 'b', 'c', 'd', 'e'])
frame.iloc[::2] = np.nan
frame
# Out:
#             a         b         c         d         e
# 0         NaN       NaN       NaN       NaN       NaN
# 1   -0.533896 -0.350893 -1.028722 -0.800988 -0.346356
# 2         NaN       NaN       NaN       NaN       NaN
# 3   -0.076207 -0.203320  1.652396  0.501572 -1.658392
# 4         NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...
# 995 -0.580285 -0.368125  0.690553 -1.616486 -0.026587
# 996       NaN       NaN       NaN       NaN       NaN
# 997 -0.929522  1.324470 -1.268444 -0.163172  0.224621
# 998       NaN       NaN       NaN       NaN       NaN
# 999  0.596069 -1.292211  0.429896  0.034882 -0.393869
#
# [1000 rows x 5 columns]

# %%
frame['f']=np.random.randn(1000)

# %%
frame
# Out:
#             a         b         c         d         e         f
# 0         NaN       NaN       NaN       NaN       NaN -1.153163
# 1   -0.533896 -0.350893 -1.028722 -0.800988 -0.346356 -1.043606
# 2         NaN       NaN       NaN       NaN       NaN -0.742504
# 3   -0.076207 -0.203320  1.652396  0.501572 -1.658392  0.248939
# 4         NaN       NaN       NaN       NaN       NaN -1.063940
# ..        ...       ...       ...       ...       ...       ...
# 995 -0.580285 -0.368125  0.690553 -1.616486 -0.026587 -0.541346
# 996       NaN       NaN       NaN       NaN       NaN -0.149701
# 997 -0.929522  1.324470 -1.268444 -0.163172  0.224621 -0.264002
# 998       NaN       NaN       NaN       NaN       NaN  1.079037
# 999  0.596069 -1.292211  0.429896  0.034882 -0.393869  0.733859
#
# [1000 rows x 6 columns]

# %%
frame['g']=np.random.uniform(1000)

# %%
frame
# Out:
#             a         b         c         d         e         f           g
# 0         NaN       NaN       NaN       NaN       NaN -1.153163  827.973814
# 1   -0.533896 -0.350893 -1.028722 -0.800988 -0.346356 -1.043606  827.973814
# 2         NaN       NaN       NaN       NaN       NaN -0.742504  827.973814
# 3   -0.076207 -0.203320  1.652396  0.501572 -1.658392  0.248939  827.973814
# 4         NaN       NaN       NaN       NaN       NaN -1.063940  827.973814
# ..        ...       ...       ...       ...       ...       ...         ...
# 995 -0.580285 -0.368125  0.690553 -1.616486 -0.026587 -0.541346  827.973814
# 996       NaN       NaN       NaN       NaN       NaN -0.149701  827.973814
# 997 -0.929522  1.324470 -1.268444 -0.163172  0.224621 -0.264002  827.973814
# 998       NaN       NaN       NaN       NaN       NaN  1.079037  827.973814
# 999  0.596069 -1.292211  0.429896  0.034882 -0.393869  0.733859  827.973814
#
# [1000 rows x 7 columns]

# %%
df = pd.DataFrame(np.random.randn(10, 4))
pieces = [df[:3], df[3:7], df[7:]]
df
# Out:
#           0         1         2         3
# 0 -0.174916 -0.288863  0.265523  1.820495
# 1 -0.099364  0.237841 -0.704033 -1.181013
# 2 -0.381694  0.056255 -1.233523  0.838889
# 3  0.681769  1.261734  1.627068  1.753333
# 4 -0.588473  0.290557  0.453191  1.238463
# 5 -1.434583 -0.726564  2.527172  0.323821
# 6 -1.254952 -0.772982 -1.512065  0.937395
# 7  0.035350  0.274924  0.562199 -0.618873
# 8 -0.608123 -0.592218  1.117178  0.940094
# 9 -0.418306  1.029604  1.354213 -1.390600

# %%
pieces
# Out:
# [          0         1         2         3
#  0 -0.306645  1.552713 -0.236694  0.020187
#  1  0.590847  0.055645  0.508506  2.484976
#  2 -0.129249  0.169879  0.303711  1.605672,
#            0         1         2         3
#  3  1.622348  2.159951 -1.119215 -0.815824
#  4 -0.213103  0.529109 -0.507019 -0.744973
#  5 -0.422576  0.178497  0.862761  1.327536
#  6  0.715340 -0.257464 -0.163382  0.353058,
#            0         1         2         3
#  7 -1.351601  1.943398 -1.384373 -0.193575
#  8  0.984599 -0.856983  0.373146  0.594491
#  9 -0.488224 -1.111921 -1.580146  0.246377]

# %%
pd.concat(pieces,axis=1,sort=True)
# Out:
#           0         1         2         3         0         1         2  \
# 0 -0.174916 -0.288863  0.265523  1.820495       NaN       NaN       NaN
# 1 -0.099364  0.237841 -0.704033 -1.181013       NaN       NaN       NaN
# 2 -0.381694  0.056255 -1.233523  0.838889       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.681769  1.261734  1.627068
# 4       NaN       NaN       NaN       NaN -0.588473  0.290557  0.453191
# 5       NaN       NaN       NaN       NaN -1.434583 -0.726564  2.527172
# 6       NaN       NaN       NaN       NaN -1.254952 -0.772982 -1.512065
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           3         0         1         2         3
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# ...

# %%
pd.concat(pieces,axis=1,sort=False)
# Out:
#           0         1         2         3         0         1         2  \
# 0 -0.174916 -0.288863  0.265523  1.820495       NaN       NaN       NaN
# 1 -0.099364  0.237841 -0.704033 -1.181013       NaN       NaN       NaN
# 2 -0.381694  0.056255 -1.233523  0.838889       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.681769  1.261734  1.627068
# 4       NaN       NaN       NaN       NaN -0.588473  0.290557  0.453191
# 5       NaN       NaN       NaN       NaN -1.434583 -0.726564  2.527172
# 6       NaN       NaN       NaN       NaN -1.254952 -0.772982 -1.512065
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           3         0         1         2         3
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# ...
