# %% [markdown]
# # HOW TO HANDLE A EXCEL FILE IN WHICH MULTIPLE EXCEL SHEETS ARE PRESENT

# %% [markdown]
# ## FOR THAT IMPORT ALL RECOMMENDED PACKAGES

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### IF THAT EXCLE FILE IS IN XLSX FORMAT

# %% [markdown]
# #### CREATE OR LOAD A FILE WHICH CONTAINS MULTIPLE SHEETS IN ONE EXCEL FILE

# %% [markdown]
# ##### IF YOU WANT TO LOAD XLSX FILE YOU TO INSTALL XLRD BY USING FOLLOWING SYNTAX
# ###### !pip install xlrd

# %% [markdown]
# ## Following is the syntax for the code
# ### variable_name= pd.concat(pd.read_excel(r"file location.xlsx",sheet_name=None),

# %%
df = pd.concat(pd.read_excel(r"C:\Users\LENOVO\Desktop\sheets.xlsx",sheet_name=None),
              ignore_index=True)

# %%
df
# Out:
#     1     20    41    61      1597    1609    1627    1973    1992    1999  \
# 0      1   NaN   NaN  62.0  1587.0     NaN     NaN     NaN     NaN  1999.0
# 1      1   NaN   NaN  63.0  1577.0     NaN     NaN     NaN     NaN  1999.0
# 2      1   NaN   NaN  64.0  1567.0     NaN     NaN     NaN     NaN  1999.0
# 3      1   NaN   NaN  65.0  1557.0     NaN     NaN     NaN     NaN  1999.0
# 4      1   NaN   NaN  66.0  1547.0     NaN     NaN     NaN     NaN  1999.0
# 5      1   NaN   NaN  67.0  1537.0     NaN     NaN     NaN     NaN  1999.0
# 6      1   NaN   NaN  68.0  1527.0     NaN     NaN     NaN     NaN  1999.0
# 7      1   NaN   NaN  69.0  1517.0     NaN     NaN     NaN     NaN  1999.0
# 8      1   NaN   NaN  70.0  1507.0     NaN     NaN     NaN     NaN  1999.0
# 9      1   NaN   NaN  71.0  1497.0     NaN     NaN     NaN     NaN  1999.0
# 10     1   NaN   NaN  72.0  1487.0     NaN     NaN     NaN     NaN  1999.0
# ...

# %% [markdown]
# #### IF YOUR FILE IS IN CSV FORMAT IN THE CODE INSTEAD OF pd.read_excel GIVE pd.read_csv
